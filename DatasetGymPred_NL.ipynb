# %%
import pandas as pd

# Load the dataset
file_path = 'data/gym_mem_pred.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dataset
df.head(), df.info(), df.describe(), df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   User ID                4000 non-null   int64
#  1   Age                    4000 non-null   int64
#  2   Gender                 4000 non-null   object
#  3   Annual Income          4000 non-null   int64
#  4   Membership Type        4000 non-null   object
#  5   Membership Duration    4000 non-null   int64
#  6   Frequency of Visit     4000 non-null   int64
#  7   Preferred Time         4000 non-null   object
#  8   Previous Membership    4000 non-null   object
#  9   Marital Status         4000 non-null   object
#  10  Location               4000 non-null   object
#  11  Promotion Response     4000 non-null   object
#  12  Health Condition       4000 non-null   object
#  13  Membership Prediction  4000 non-null   object
# ...

# %%
import matplotlib.pyplot as plt

# 1. Distribution of Numerical Variables
plt.figure(figsize=(14, 10))

numerical_cols = ['Age', 'Annual Income', 'Membership Duration', 'Frequency of Visit']

for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    plt.hist(df[col], bins=30, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# 2. Count Plots for Categorical Variables
plt.figure(figsize=(18, 20))

categorical_cols = ['Gender', 'Membership Type', 'Preferred Time', 'Previous Membership', 
                    'Marital Status', 'Location', 'Promotion Response', 'Health Condition', 
                    'Membership Prediction', 'Professional', 'Professional Status']

for i, col in enumerate(categorical_cols):
    plt.subplot(4, 3, i + 1)
    df[col].value_counts().plot(kind='bar', color='lightcoral', edgecolor='black')
    plt.title(f'Count of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# 3. Correlation Matrix for Numerical Variables
plt.figure(figsize=(10, 6))
corr_matrix = df[numerical_cols].corr()

plt.imshow(corr_matrix, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(numerical_cols)), numerical_cols, rotation=45)
plt.yticks(range(len(numerical_cols)), numerical_cols)
plt.title('Correlation Matrix')

# Adding correlation coefficients on the heatmap
for i in range(len(numerical_cols)):
    for j in range(len(numerical_cols)):
        plt.text(j, i, f'{corr_matrix.iloc[i, j]:.2f}', ha='center', va='center', color='black')

plt.show()
